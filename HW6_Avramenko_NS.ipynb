# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from keras.preprocessing import image
import tensorflow as tf

# %%
# !pip install keras
# Out:
# Collecting keras
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 307.1 kB/s eta 0:00:00
# Installing collected packages: keras
# Successfully installed keras-2.12.0
# WARNING: There was an error checking the latest version of pip.

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
# WARNING: There was an error checking the latest version of pip.
#   Using cached tensorflow-2.12.0-cp39-cp39-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.12.0
#   Using cached tensorflow_intel-2.12.0-cp39-cp39-win_amd64.whl (272.8 MB)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: setuptools in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.5.0)
# Requirement already satisfied: packaging in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (21.3)
# Requirement already satisfied: numpy<1.24,>=1.22 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.4.0)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: termcolor>=1.1.0 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.2.0)
# Collecting jax>=0.3.15
#   Using cached jax-0.4.8-py3-none-any.whl
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.22.3)
# Requirement already satisfied: keras<2.13,>=2.12.0 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Collecting tensorboard<2.13,>=2.12
#   Using cached tensorboard-2.12.2-py3-none-any.whl (5.6 MB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.54.0-cp39-cp39-win_amd64.whl (4.1 MB)
# Requirement already satisfied: libclang>=13.0.0 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: flatbuffers>=2.0 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.3.3)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: six>=1.12.0 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\users\aavramenko\anaconda4\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.37.1)
# Collecting ml-dtypes>=0.0.3
#   Using cached ml_dtypes-0.1.0-cp39-cp39-win_amd64.whl (120 kB)
# Requirement already satisfied: scipy>=1.7 in d:\users\aavramenko\anaconda4\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.9.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.3)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.17.3-py2.py3-none-any.whl (178 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in d:\users\aavramenko\anaconda4\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.3.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\users\aavramenko\anaconda4\lib\site-packages (from packaging->tensorflow-intel==2.12.0->tensorflow) (3.0.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\users\aavramenko\anaconda4\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\users\aavramenko\anaconda4\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\aavramenko\anaconda4\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aavramenko\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aavramenko\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aavramenko\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\users\aavramenko\anaconda4\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\users\aavramenko\anaconda4\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# Installing collected packages: opt-einsum, ml-dtypes, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, requests-oauthlib, jax, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
# Successfully installed absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.0 gast-0.4.0 google-auth-2.17.3 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.54.0 jax-0.4.8 ml-dtypes-0.1.0 opt-einsum-3.3.0 requests-oauthlib-1.3.1 tensorboard-2.12.2 tensorflow-2.12.0 tensorflow-intel-2.12.0

# %%
class_dict = pd.read_csv('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/class_dict.csv')

# %%
path_train = 'D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/'
path_train_labels = 'D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train_labels/'
path_test = 'D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/test/'
path_test_labels = 'D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/test_labels/'
path_val = 'D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/val/'
path_val_labels = 'D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/val_labels/'



train_images_paths = list(Path(path_train).iterdir())

train_images_paths
# Out:
# [WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_009210.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_009240.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_009390.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_009420.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_009450.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_009480.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_009510.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_009540.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_009690.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_009720.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_009750.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_009780.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_009810.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_009840.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_009990.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_010020.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_010050.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_010080.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_010110.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_010140.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_010290.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_010320.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_010350.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0001TP_010380.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f00930.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f00960.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01110.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01140.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01170.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01200.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01230.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01260.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01410.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01440.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01470.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01500.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01530.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01560.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01710.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01740.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01770.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01800.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01830.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f01860.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02010.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02040.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02070.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02100.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02130.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02160.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02310.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02340.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02370.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02400.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02430.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02460.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02610.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02640.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02670.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02700.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02730.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02760.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02910.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02940.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f02970.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03000.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03030.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03060.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03210.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03240.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03270.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03300.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03330.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03360.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03510.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03540.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03570.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03600.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03630.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03660.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03810.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03840.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03870.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03900.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0006R0_f03930.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_00390.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_00540.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_00570.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_00600.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_00630.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_00660.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_00690.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_00840.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_00870.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_00901.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_00930.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_00960.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_00990.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01140.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01170.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01200.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01230.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01260.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01290.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01440.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01470.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01500.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01530.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01560.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01590.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01740.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01770.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01800.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01830.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01860.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_01890.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_02040.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_02070.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_02100.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_02130.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_02160.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_02190.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_02340.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_02370.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_02400.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_04350.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_04380.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_04410.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_04560.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_04590.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_04620.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_04650.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_04680.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_04710.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_04860.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_04890.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_04920.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_04950.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_04980.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05010.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05160.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05190.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05220.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05250.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05280.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05310.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05460.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05490.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05520.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05550.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05580.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05610.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05760.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05790.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05820.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05850.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05880.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_05910.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06060.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06090.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06120.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06150.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06180.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06210.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06360.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06390.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06420.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06450.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06480.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06510.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06660.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06690.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06720.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06750.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06780.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06810.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06960.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_06990.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07020.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07050.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07080.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07110.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07260.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07290.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07320.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07350.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07380.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07410.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07560.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07590.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07620.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07650.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07680.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07710.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07860.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07890.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07920.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07959.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07961.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07963.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07973.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07975.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07977.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07979.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07981.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07983.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07993.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07995.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07997.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_07999.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08001.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08003.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08013.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08015.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08017.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08019.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08021.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08023.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08033.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08035.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08037.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08039.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08041.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08043.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08053.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08055.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08057.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08059.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08061.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08063.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08073.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08075.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08077.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08079.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08081.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08083.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08093.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08095.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08097.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08099.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08101.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08103.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08113.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08115.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08117.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08119.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08121.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08123.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08133.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08135.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08137.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08139.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08141.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08143.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08153.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08155.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08157.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08159.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08190.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08220.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08370.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08400.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08430.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08460.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08490.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/0016E5_08520.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00000.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00030.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00060.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00090.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00120.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00150.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00300.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00330.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00360.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00390.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00420.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00450.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00600.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00630.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00660.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00690.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00720.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00750.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00900.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00930.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00960.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f00990.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01020.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01050.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01200.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01230.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01260.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01290.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01320.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01350.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01500.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01530.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01560.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01590.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01620.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01650.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01800.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01830.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01860.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01890.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01920.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f01950.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02100.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02130.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02160.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02190.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02220.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02250.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02400.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02430.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02460.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02490.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02520.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02550.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02700.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02730.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02760.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02790.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02820.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f02850.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03000.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03030.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03060.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03090.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03120.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03150.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03300.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03330.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03360.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03390.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03420.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03450.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03600.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03630.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03660.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03690.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03720.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03750.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03900.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03930.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03960.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f03990.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04020.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04050.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04200.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04230.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04260.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04290.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04320.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04350.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04500.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04530.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04560.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04590.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04620.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04650.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04800.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04830.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04860.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04890.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04920.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f04950.png'),
#  WindowsPath('D:/КУРСЫ/GeekBrains/Нейронные сети/CamVid/train/Seq05VD_f05100.png')]

# %%
single_image = tf.keras.utils.load_img(train_images_paths[0])
image_size = (int(single_image.size[0]/2), single_image.size[1])
image_size
# Out:
# (480, 720)

# %%
train_imgs_paths = list(sorted(Path(path_train).iterdir()))
train_masks_paths = list(sorted(Path(path_train_labels).iterdir()))
test_imgs_paths = list(sorted(Path(path_test).iterdir()))
test_masks_paths = list(sorted(Path(path_test_labels).iterdir()))
val_imgs_paths = list(sorted(Path(path_val).iterdir()))
val_masks_paths = list(sorted(Path(path_val_labels).iterdir()))

# %%
image_size = (128, 192)

# %%
train_images = []
train_masks = []

for i_img, i_mask in zip(train_imgs_paths, train_masks_paths):
    train_images.append(tf.keras.utils.load_img(i_img, target_size=image_size))
    train_masks.append(tf.keras.utils.load_img(i_mask, target_size=image_size))

# %%
test_images = []
test_masks = []

for i_img, i_mask in zip(test_imgs_paths, test_masks_paths):
    test_images.append(tf.keras.utils.load_img(i_img, target_size=image_size))
    test_masks.append(tf.keras.utils.load_img(i_mask, target_size=image_size))

# %%
val_images = []
val_masks = []

for i_img, i_mask in zip(val_imgs_paths, val_masks_paths):
    val_images.append(tf.keras.utils.load_img(i_img, target_size=image_size))
    val_masks.append(tf.keras.utils.load_img(i_mask, target_size=image_size))

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 12))
ax[0].imshow(train_images[80].convert('RGBA'))
ax[1].imshow(train_masks[80].convert('RGBA'))

# %%
X_train = []

for img in train_images:
  x = tf.keras.utils.img_to_array(img)
  X_train.append(x)

X_train = np.array(X_train)
print(X_train.shape)
# Out:
# (369, 128, 192, 3)

# %%
X_test = []

for img in test_images:
  x = tf.keras.utils.img_to_array(img)
  X_test.append(x)

X_test = np.array(X_test)
print(X_test.shape)
# Out:
# (232, 128, 192, 3)

# %%
X_val = []

for img in val_images:
  x = tf.keras.utils.img_to_array(img)
  X_val.append(x)

X_val = np.array(X_val)
print(X_val.shape)
# Out:
# (100, 128, 192, 3)

# %%
class_dict
# Out:
#                  name    r    g    b
# 0              Animal   64  128   64
# 1             Archway  192    0  128
# 2           Bicyclist    0  128  192
# 3              Bridge    0  128   64
# 4            Building  128    0    0
# 5                 Car   64    0  128
# 6     CartLuggagePram   64    0  192
# 7               Child  192  128   64
# 8         Column_Pole  192  192  128
# 9               Fence   64   64  128
# 10       LaneMkgsDriv  128    0  192
# 11    LaneMkgsNonDriv  192    0   64
# 12          Misc_Text  128  128   64
# 13  MotorcycleScooter  192    0  192
# 14        OtherMoving  128   64   64
# 15       ParkingBlock   64  192  128
# 16         Pedestrian   64   64    0
# 17               Road  128   64  128
# 18       RoadShoulder  128  128  192
# 19           Sidewalk    0    0  192
# 20         SignSymbol  192  128  128
# 21                Sky  128  128  128
# 22     SUVPickupTruck   64  128  192
# 23        TrafficCone    0    0   64
# 24       TrafficLight    0   64   64
# 25              Train  192   64  128
# 26               Tree  128  128    0
# 27          Truck_Bus  192  128  192
# 28             Tunnel   64    0   64
# 29     VegetationMisc  192  192    0
# 30               Void    0    0    0
# 31               Wall   64  192    0

# %%
arr_col = []

for r, g, b in zip(class_dict['r'], class_dict['g'], class_dict['b']):
  arr_col.append([r, g, b])

# %%
import cv2


def Color2index(y, arr_col=arr_col):

    y_ind = np.zeros((y.shape[0], y.shape[1]))
    y_cat = np.zeros((y.shape[0], y.shape[1], len(arr_col)))
    i = 1
    for i_color in arr_col:
        ind_i = np.where(
            (y[..., 0] == i_color[0]) 
            & (y[..., 1] == i_color[1])
            & (y[..., 2] == i_color[2])
        )
        y_ind[ind_i[0], ind_i[1]] = i
        y_cat[ind_i[0], ind_i[1], i-1] = 1 
        i += 1
    
    return y_cat, y_ind#, i-1

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.7.0.72-cp37-abi3-win_amd64.whl (38.2 MB)
#      -------------------------------------- 38.2/38.2 MB 748.2 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.0 in d:\users\aavramenko\anaconda4\lib\site-packages (from opencv-python) (1.23.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.7.0.72
# WARNING: There was an error checking the latest version of pip.

# %%
cat_yi, ind_yi = Color2index(tf.keras.utils.img_to_array(train_masks[3]))
plt.imshow(ind_yi)
plt.show()

# %%
ind_yi
# Out:
# array([[22., 22., 22., ..., 27., 27., 27.],
#        [22., 22., 22., ..., 27., 27., 27.],
#        [22., 22., 22., ..., 27., 27., 27.],
#        ...,
#        [20., 20., 20., ..., 31., 31., 31.],
#        [20., 20., 20., ..., 31., 31., 31.],
#        [20., 20., 20., ..., 31., 31., 31.]])

# %%
plt.imshow(cat_yi[..., 17])
plt.show()

# %%
cat_yi.shape
# Out:
# (128, 192, 32)

# %%
y_train = []

for mask in train_masks:
  y_cat, _ = Color2index(tf.keras.utils.img_to_array(mask))
  y_train.append(y_cat)

y_train = np.array(y_train)

# %%
n = 0
plt.imshow(train_masks[n].convert('RGBA'))
plt.show()
img = y_train[n][..., 22]

plt.imshow(img)
plt.show()

# %%
y_test = []

for mask in test_masks:
  y_cat, _ = Color2index(tf.keras.utils.img_to_array(mask))
  y_test.append(y_cat)

y_test = np.array(y_test)

# %%
y_val = []

for mask in val_masks:
  y_cat, _ = Color2index(tf.keras.utils.img_to_array(mask))
  y_val.append(y_cat)

y_val = np.array(y_val)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (369, 128, 192, 3)
# (369, 128, 192, 32)

# %%
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.models import Model, Sequential
from keras.layers import (Activation, Input, MaxPooling2D, BatchNormalization, 
                          Conv2D, Conv2DTranspose, concatenate)
from tensorflow.keras.utils import plot_model


def unet_pre_train(num_classes=32, input_shape=(128, 162, 3)):    
    pre_trained_model = VGG16(input_shape=input_shape, include_top=False, weights='imagenet')

    for layer in pre_trained_model.layers[:-5]:
        layer.trainable = False

    x = pre_trained_model.layers[13].output
    block_4_out = pre_trained_model.layers[10].output
    block_3_out = pre_trained_model.layers[6].output
    block_2_out = pre_trained_model.layers[3].output
    img_input = pre_trained_model.inputs
    print(block_4_out)
    print(block_3_out)
    print(block_2_out)
   
    # UP 1

    # добавили перенос из VGG16
    x = concatenate([x, block_4_out])
    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)


    # UP 2
    x = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # добавили перенос из VGG16
    x = concatenate([x, block_3_out])
    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)


    # UP 3
    x = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # добавили перенос из VGG16
    x = concatenate([x, block_2_out])
    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)


    # UP 4
    x = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_classes, (3, 3), activation='softmax', padding='same')(x)

    model = Model(img_input, x)
    return model

# %%
model = unet_pre_train(32, (128, 192, 3))

plot_model(model, to_file='model.png', show_shapes=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 134s 2us/step
# KerasTensor(type_spec=TensorSpec(shape=(None, 16, 24, 256), dtype=tf.float32, name=None), name='block3_pool/MaxPool:0', description="created by layer 'block3_pool'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 32, 48, 128), dtype=tf.float32, name=None), name='block2_pool/MaxPool:0', description="created by layer 'block2_pool'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 64, 96, 64), dtype=tf.float32, name=None), name='block1_pool/MaxPool:0', description="created by layer 'block1_pool'")

# %%
import keras.backend as K

def dice_coef(y_true, y_pred):
    return (2. * K.sum(y_true * y_pred)) / (K.sum(y_true) + K.sum(y_pred))

# %%
from tensorflow.keras.optimizers import Adam


model.compile(optimizer=Adam(),
                loss='categorical_crossentropy',
                metrics=[dice_coef])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 192, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 128, 192, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 128, 192, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 64, 96, 64)   0           ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 64, 96, 128)  73856       ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 64, 96, 128)  147584      ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 32, 48, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 32, 48, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 32, 48, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 32, 48, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 16, 24, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 16, 24, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 16, 24, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 16, 24, 512)  2359808     ['block4_conv2[0][0]']
#
#  concatenate (Concatenate)      (None, 16, 24, 768)  0           ['block4_conv3[0][0]',
#                                                                   'block3_pool[0][0]']
#
#  conv2d (Conv2D)                (None, 16, 24, 256)  1769728     ['concatenate[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 24, 256)  1024       ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 16, 24, 256)  0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 16, 24, 256)  590080      ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 24, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 16, 24, 256)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 48, 256)  262400     ['activation_1[0][0]']
#  ose)
#
#  batch_normalization_2 (BatchNo  (None, 32, 48, 256)  1024       ['conv2d_transpose[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 32, 48, 256)  0           ['batch_normalization_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 48, 384)  0           ['activation_2[0][0]',
#                                                                   'block2_pool[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 48, 256)  884992      ['concatenate_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 48, 256)  1024       ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 48, 256)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 48, 256)  590080      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 48, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 48, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 96, 128)  131200     ['activation_4[0][0]']
#  spose)
#
#  batch_normalization_5 (BatchNo  (None, 64, 96, 128)  512        ['conv2d_transpose_1[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 96, 128)  0           ['batch_normalization_5[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 64, 96, 192)  0           ['activation_5[0][0]',
#                                                                   'block1_pool[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 96, 128)  221312      ['concatenate_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 96, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 96, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 96, 128)  147584      ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 96, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 96, 128)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 192, 64  32832      ['activation_7[0][0]']
#  spose)                         )
#
#  batch_normalization_8 (BatchNo  (None, 128, 192, 64  256        ['conv2d_transpose_2[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 128, 192, 64  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 128, 192, 64  36928       ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 128, 192, 64  256        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 128, 192, 64  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 128, 192, 64  36928       ['activation_9[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 128, 192, 64  256        ['conv2d_7[0][0]']
#  ormalization)                  )
#
#  activation_10 (Activation)     (None, 128, 192, 64  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 128, 192, 32  18464       ['activation_10[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 12,365,216
# Trainable params: 4,726,240
# Non-trainable params: 7,638,976
# __________________________________________________________________________________________________

# %%
sample_image = X_test[1]
sample_mask = y_test[1]

# %%
import keras
from IPython.display import clear_output


def show_predictions(model):
    pred_mask = model.predict(sample_image[None])[..., 16]
    print(pred_mask.shape)

    fig, ax = plt.subplots(1, 3, figsize=(15, 8))

    ax[0].imshow(sample_image / 255.0)
    ax[1].imshow(sample_mask[..., 16])
    ax[2].imshow(np.squeeze(pred_mask, axis=0))
    plt.show()


class DisplayCallback(keras.callbacks.Callback):
    def __init__(self, patience=1):
        super().__init__()
        self.patience = patience
    
    def on_train_begin(self, logs=None):
        self.wait = 0

    def on_epoch_end(self, epoch, logs=None):
        self.wait += 1
        if self.wait >= self.patience:
            clear_output(wait=True)
            show_predictions(self.model)
            print(f'\nSample Prediction after epoch {epoch+1}')
            self.wait = 0

# %%
show_predictions(model)
# Out:
# 1/1 [==============================] - 1s 1s/step
# (1, 128, 192)

# %%
history = model.fit(preprocess_input(X_train), y_train,
                      epochs=20,
                      batch_size=10,
                      validation_data=(preprocess_input(X_test), y_test),
                      callbacks=[DisplayCallback(patience=5)])
# Out:
# 1/1 [==============================] - 1s 509ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1, 128, 192)
# Sample Prediction after epoch 20
# 37/37 [==============================] - 459s 12s/step - loss: 0.3431 - dice_coef: 0.8446 - val_loss: 0.6423 - val_dice_coef: 0.7716

# %%
plt.plot(history.history['val_dice_coef'], label='test')
plt.plot(history.history['dice_coef'], label='train')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('dice_coef')
plt.show()

# %%
pred = model.predict(X_val)
print(pred.shape)
# Out:
# 4/4 [==============================] - 37s 8s/step
# (100, 128, 192, 32)

# %%
n = 1
class_ = 17
plt.imshow(val_images[n].convert('RGBA'))
plt.title('входной кадр')
plt.show()
plt.imshow(val_masks[n].convert('RGBA'))
plt.title('целевая разметка')
plt.show()
img = y_val[n][..., class_]
plt.imshow(img)
plt.title('целевая разметка класс: ' + str(class_))
plt.show()
img = pred[n][..., class_]
plt.imshow(img)
plt.title('предиктивная разметка класс: ' + str(class_))
plt.show()
